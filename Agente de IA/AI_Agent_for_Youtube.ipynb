# %% [markdown]
# <a href="https://colab.research.google.com/github/daniel-usp/MBA-BIA-USP/blob/main/AI_Agent_for_Youtube.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain==0.3.0
# !pip install langchain-groq==0.2.0
# !pip install langchain-community==0.3.0
# !pip install youtube_transcript_api==0.6.2
# !pip install pypdf==5.0.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 1.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 23.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.2/407.2 kB 19.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.8/295.8 kB 13.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.5/106.5 kB 1.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Aula 8: Acessando vídeos de Youtube e PDFs

# %%
import os
from langchain_groq import ChatGroq
from langchain.prompts import ChatPromptTemplate

api_key = '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'

os.environ['GROQ_API_KEY'] = api_key

chat = ChatGroq(model='llama-3.1-70b-versatile')

# %% [markdown]
# ## Acessando o Youtube

# %% [markdown]
# E agora vamos mostrar o quão fácil é de acessar vídeos de youtube utilizando LangChain!

# %%
from langchain_community.document_loaders import YoutubeLoader

url = 'https://www.youtube.com/watch?v=nLopLwffsLI&ab_channel=AsimovAcademy'
# Out:
# 'Se eu soubesse que programação era tão difícil teria desistido antes galera eu já ensino programação há quase 6 anos Comecei em 2017 aqui na internet com alguns cursos da udem mas também já dei muitas aulas presenciais em algumas empresas e esse tipo de comentário aqui é com certeza o mais comum pessoas que estão começando na programação ou Tão tentando há bastante tempo e não conseguem se tornar autossuficientes às vezes entendem os códigos de outros só que quando tentam desenvolver os próprios não conseguem eu decidi criar esse vídeo de maneira bem honesta mesmo para poder trazer minha opinião sobre o tema programação é para todos e ao longo desses anos eu não só ensinei pessoas na internet presencialmente como eu também contratei muitas pessoas dentro das imov trading trabalhei com programadores lado a lado eu pude ver que algumas pessoas T uma diferença muito grande em um aspecto específico da programação que faz com que toda a diferença ocorra mas se tu é uma das pessoas que se
# ...

# %%
# Out:
# O autor do vídeo começou a aprender programação quando tinha 12 anos de idade, o que faz aproximadamente 20 anos.

# %% [markdown]
# ## Acessando PDFs
